# %%
li = [1,2,3,4,5,6,7,8,9]
def square(x):
  return x*x
squared_list = list(map(square,li))
print(squared_list)

# %%
l2 = [2,3,4,5,6,7,8]
filtered_l2 = filter(lambda x:x%2==1, l2)
print(list(filtered_l2))

# %%
import functools
from functools import reduce
l3 = [1,2,3,4,5,6,7,8,9]
sum= reduce(lambda acc, x: acc+x,l3)
print(sum)

# %%
reduce?

# %% [markdown]
# test comment to check modification
